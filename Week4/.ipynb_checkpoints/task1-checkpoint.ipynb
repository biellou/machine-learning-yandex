# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as sts
# %matplotlib inline

# Инициализарую gamma_r гамма-распределением (k=2;theta=5), геренирую выборку размером в 1000, рисую гистограмму выборки
k = 3.
theta = 2.
gamma_r = sts.gamma(k,theta)
sample = gamma_r.rvs(1000)
plt.hist(sample, normed=True, label = 'distr')

# инициализирую x списком из 100 элементов от -1 до 10. Считаю плотность вероятности, рисую кк
x = np.linspace(-1,10,100)
pdf = gamma_r.pdf(x)
plt.plot(x, pdf, label='theoretical pdf')

# Наношу легенду на график
plt.legend()
plt.ylabel('f(x)')
plt.xlabel('x')
# Out:
# Text(0.5,0,u'x')

# %%
sample_number = (5,10,50)

mu = gamma_r.mean()

init_x = np.linspace(0,8,100)

for x in sample_number:
    
    sample = []
    for i in range (1, 1000):
        sample.append(gamma_r.rvs(x))
    meanX = []
    
    for i in sample:
        meanX.append(np.mean(i))
    plt.figure()
    plt.title('n = %s' %x)
    
    plt.hist(meanX, normed=True)
    
    sigma = (gamma_r.var()/x)**0.5
    norm_rv = sts.norm(mu, sigma)
    norm_pdf = norm_rv.pdf(init_x)
    plt.plot(init_x, norm_pdf, label='theoretic pdf')
    
    plt.legend(loc='upper right')

# %%
# ?sts.norm
